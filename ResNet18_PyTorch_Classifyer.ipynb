# %% [markdown]
# <a href="http://cocl.us/pytorch_link_top">
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/Pytochtop.png" width="750" alt="IBM Product ">
# </a>

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0321EN-SkillsNetwork/image/IDSN-logo.png" width="200" alt="cognitiveclass.ai logo">

# %% [markdown]
# <h1><h1>Pre-trained-Models with PyTorch </h1>

# %% [markdown]
# In this lab, you will use pre-trained models to classify between the negative and positive samples; you will be provided with the dataset object. The particular pre-trained model will be resnet18; you will have three questions:
# <ul>
# <li>change the output layer</li>
# <li> train the model</li>
# <li>  identify  several  misclassified samples</li>
#  </ul>
# You will take several screenshots of your work and share your notebook.

# %% [markdown]
# <h2>Table of Contents</h2>

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
#
# <ul>
#     <li><a href="#download_data"> Download Data</a></li>
#     <li><a href="#auxiliary"> Imports and Auxiliary Functions </a></li>
#     <li><a href="#data_class"> Dataset Class</a></li>
#     <li><a href="#Question_1">Question 1</a></li>
#     <li><a href="#Question_2">Question 2</a></li>
#     <li><a href="#Question_3">Question 3</a></li>
# </ul>
# <p>Estimated Time Needed: <strong>120 min</strong></p>
#  </div>
# <hr>

# %% [markdown]
# <h2 id="download_data">Download Data</h2>

# %% [markdown]
# Download the dataset and unzip the files in your data directory, unlike the other labs, all the data will be deleted after you close  the lab, this may take some time:

# %%
# !wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Positive_tensors.zip
# Out:
# --2025-06-06 14:15:29--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Positive_tensors.zip
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196, 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2598656062 (2.4G) [application/zip]
# Saving to: ‘Positive_tensors.zip.1’
#
# Positive_tensors.zi 100%[===================>]   2.42G  60.9MB/s    in 43s
#
# 2025-06-06 14:16:20 (58.0 MB/s) - ‘Positive_tensors.zip.1’ saved [2598656062/2598656062]

# %%
# !unzip -qo Positive_tensors.zip

# %%
# !wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Negative_tensors.zip
# !unzip -qo Negative_tensors.zip
# Out:
# --2025-06-06 14:58:33--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Negative_tensors.zip
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196, 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2111408108 (2.0G) [application/zip]
# Saving to: ‘Negative_tensors.zip.1’
#
# Negative_tensors.zi 100%[===================>]   1.97G  47.5MB/s    in 41s
#
# 2025-06-06 14:59:19 (49.6 MB/s) - ‘Negative_tensors.zip.1’ saved [2111408108/2111408108]

# %% [markdown]
# We will install torchvision:

# %%
# !pip install torchvision
# Out:
# Requirement already satisfied: torchvision in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (0.14.1+cpu)
# Requirement already satisfied: typing-extensions in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from torchvision) (4.5.0)
# Requirement already satisfied: numpy in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from torchvision) (1.21.6)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from torchvision) (2.29.0)
# Requirement already satisfied: torch==1.13.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from torchvision) (1.13.1+cpu)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from torchvision) (8.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->torchvision) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->torchvision) (2023.5.7)

# %% [markdown]
# <h2 id="auxiliary">Imports and Auxiliary Functions</h2>

# %% [markdown]
# The following are the libraries we are going to use for this lab. The <code>torch.manual_seed()</code> is for forcing the random function to give the same number every time we try to recompile it.

# %%
# These are the libraries will be used for this lab.
import torchvision.models as models
from PIL import Image
import pandas
from torchvision import transforms
import torch.nn as nn
import time
import torch 
import matplotlib.pylab as plt
import numpy as np
from torch.utils.data import Dataset, DataLoader
import h5py
import os
import glob
torch.manual_seed(0)

# %%
from matplotlib.pyplot import imshow
import matplotlib.pylab as plt
from PIL import Image
import pandas as pd
import os

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="data_class">Dataset Class</h2>

# %% [markdown]
#  This dataset class is essentially the same dataset you build in the previous section, but to speed things up, we are going to use tensors instead of jpeg images. Therefor for each iteration, you will skip the reshape step, conversion step to tensors and normalization step.

# %%
# Create your own dataset object

class Dataset(Dataset):

    # Constructor
    def __init__(self,transform=None,train=True):
        directory="/resources/DL0321EN/labs/Week4"
        positive="Positive_tensors"
        negative='Negative_tensors'

        positive_file_path=os.path.join(directory,positive)
        negative_file_path=os.path.join(directory,negative)
        positive_files=[os.path.join(positive_file_path,file) for file in os.listdir(positive_file_path) if file.endswith(".pt")]
        negative_files=[os.path.join(negative_file_path,file) for file in os.listdir(negative_file_path) if file.endswith(".pt")]
        number_of_samples=len(positive_files)+len(negative_files)
        self.all_files=[None]*number_of_samples
        self.all_files[::2]=positive_files
        self.all_files[1::2]=negative_files 
        # The transform is goint to be used on image
        self.transform = transform
        #torch.LongTensor
        self.Y=torch.zeros([number_of_samples]).type(torch.LongTensor)
        self.Y[::2]=1
        self.Y[1::2]=0
        
        if train:
            self.all_files=self.all_files[0:30000]
            self.Y=self.Y[0:30000]
            self.len=len(self.all_files)
        else:
            self.all_files=self.all_files[30000:]
            self.Y=self.Y[30000:]
            self.len=len(self.all_files)     
       
    # Get the length
    def __len__(self):
        return self.len
    
    # Getter
    def __getitem__(self, idx):
               
        image=torch.load(self.all_files[idx])
        y=self.Y[idx]
                  
        # If there is any transform method, apply it onto the image
        if self.transform:
            image = self.transform(image)

        return image, y
    
print("done")
# Out:
# done

# %% [markdown]
# We create two dataset objects, one for the training data and one for the validation data.

# %%
train_dataset = Dataset(train=True)
validation_dataset = Dataset(train=False)
print("done")
# Out:
# done

# %% [markdown]
# <h2 id="Question_1">Question 1</h2>

# %% [markdown]
# <b>Prepare a pre-trained resnet18 model :</b>

# %% [markdown]
# <b>Step 1</b>: Load the pre-trained model <code>resnet18</code> Set the parameter <code>pretrained</code> to true:

# %%
# Step 1: Load the pre-trained model resnet18

# Type your code here
model = models.resnet18(pretrained = True)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and may be removed in the future, "
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /home/jupyterlab/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %% [markdown]
# <b>Step 2</b>: Set the attribute <code>requires_grad</code> to <code>False</code>. As a result, the parameters will not be affected by training.

# %%
# Step 2: Set the parameter cannot be trained for the pre-trained model


# Type your code here
for parameters in model.parameters():
    parameters.requires_grad = False

# %% [markdown]
# <code>resnet18</code> is used to classify 1000 different objects; as a result, the last layer has 1000 outputs.  The 512 inputs come from the fact that the previously hidden layer has 512 outputs.

# %% [markdown]
# <b>Step 3</b>: Replace the output layer <code>model.fc</code> of the neural network with a <code>nn.Linear</code> object, to classify 2 different classes. For the parameters <code>in_features </code> remember the last hidden layer has 512 neurons.

# %%
model.fc = nn.Linear(512, 2)

# %% [markdown]
# Print out the model in order to show whether you get the correct answer.<br> <b>(Your peer reviewer is going to mark based on what you print here.)</b>

# %%
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %% [markdown]
# <h2 id="Question_2">Question 2: Train the Model</h2>

# %% [markdown]
# In this question you will train your, model:

# %% [markdown]
# <b>Step 1</b>: Create a cross entropy criterion function

# %%
# Step 1: Create the loss function

# Type your code here
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# <b>Step 2</b>: Create a training loader and validation loader object, the batch size should have 100 samples each.

# %%
train_loader = DataLoader(dataset= train_dataset, batch_size = 100)
validation_loader = DataLoader(dataset = validation_dataset, batch_size = 100)

# %% [markdown]
# <b>Step 3</b>: Use the following optimizer to minimize the loss

# %%
optimizer = torch.optim.Adam([parameters  for parameters in model.parameters() if parameters.requires_grad],lr=0.001)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# **Complete the following code to calculate  the accuracy on the validation data for one epoch; this should take about 45 minutes. Make sure you calculate the accuracy on the validation data.**

# %%
n_epochs=1
loss_list=[]
accuracy_list=[]
correct=0
N_test=len(validation_dataset)
N_train=len(train_dataset)
start_time = time.time()
batch_size = 100
#n_epochs
All_start_time = time.time()
Loss=0

for epoch in range(n_epochs):
    for i, (x, y) in enumerate(train_loader):
        start_time = time.time()
        print('-' * 30)
        print('Iteration (train phase) {}/{}'.format(i+1, int(N_train/batch_size)))
        model.train() 
        #clear gradient 
        optimizer.zero_grad()
        #make a prediction 
        z = model(x)
        # calculate loss 
        loss = criterion(z,y)
        # calculate gradients of parameters 
        loss.backward()
        # update parameters 
        optimizer.step()
        loss_list.append(loss.item())
        print('Finished in : {}'.format(time.time() - start_time))
    correct=0
    
    model.eval()
    with torch.no_grad():
        for i, (x_test, y_test) in enumerate(validation_loader):
            z = model(x_test)
            _, y_hat = torch.max(z.data,1)
            print('-' * 30)
            print('Iteration (validation phase) {}/{}'.format(i+1, int(N_test/batch_size)))
            #Calculate misclassified  samples in mini-batch 
            #hint +=(yhat==y_test).sum().item()
            correct += (y_hat == y_test).sum().item()
    
    accuracy=correct/N_test
    accuracy_list.append(accuracy)
    print(f"Epoch {epoch+1}, Accuracy: {accuracy:.4f}")
    print(f"All finished in : {time.time() - All_start_time}")
# Out:
# ------------------------------
# Iteration (train phase) 1/300
# Finished in : 8.625081777572632
# ------------------------------
# Iteration (train phase) 2/300
# Finished in : 8.837377309799194
# ------------------------------
# Iteration (train phase) 3/300
# Finished in : 8.676453828811646
# ------------------------------
# Iteration (train phase) 4/300
# Finished in : 8.339145421981812
# ------------------------------
# Iteration (train phase) 5/300
# Finished in : 8.500505208969116
# ------------------------------
# Iteration (train phase) 6/300
# Finished in : 9.060884237289429
# ------------------------------
# Iteration (train phase) 7/300
# Finished in : 8.894376516342163
# ------------------------------
# Iteration (train phase) 8/300
# Finished in : 8.216686248779297
# ------------------------------
# Iteration (train phase) 9/300
# Finished in : 8.057093143463135
# ------------------------------
# Iteration (train phase) 10/300
# Finished in : 7.658031463623047
# ------------------------------
# Iteration (train phase) 11/300
# Finished in : 8.027218103408813
# ------------------------------
# Iteration (train phase) 12/300
# Finished in : 8.587491035461426
# ------------------------------
# Iteration (train phase) 13/300
# Finished in : 8.755524158477783
# ------------------------------
# Iteration (train phase) 14/300
# Finished in : 8.688078880310059
# ------------------------------
# Iteration (train phase) 15/300
# Finished in : 8.459299325942993
# ------------------------------
# Iteration (train phase) 16/300
# Finished in : 8.486647605895996
# ------------------------------
# Iteration (train phase) 17/300
# Finished in : 8.336611986160278
# ------------------------------
# Iteration (train phase) 18/300
# Finished in : 8.37410283088684
# ------------------------------
# Iteration (train phase) 19/300
# Finished in : 8.319518804550171
# ------------------------------
# Iteration (train phase) 20/300
# Finished in : 8.59755253791809
# ------------------------------
# Iteration (train phase) 21/300
# Finished in : 8.555553197860718
# ------------------------------
# Iteration (train phase) 22/300
# Finished in : 8.733418703079224
# ------------------------------
# Iteration (train phase) 23/300
# Finished in : 8.558023452758789
# ------------------------------
# Iteration (train phase) 24/300
# Finished in : 8.100927591323853
# ------------------------------
# Iteration (train phase) 25/300
# Finished in : 8.182607412338257
# ------------------------------
# Iteration (train phase) 26/300
# Finished in : 8.114352703094482
# ------------------------------
# Iteration (train phase) 27/300
# Finished in : 7.692410945892334
# ------------------------------
# Iteration (train phase) 28/300
# Finished in : 8.174260377883911
# ------------------------------
# Iteration (train phase) 29/300
# Finished in : 7.8115010261535645
# ------------------------------
# Iteration (train phase) 30/300
# Finished in : 8.322117805480957
# ------------------------------
# Iteration (train phase) 31/300
# Finished in : 8.354367971420288
# ------------------------------
# Iteration (train phase) 32/300
# Finished in : 7.7774059772491455
# ------------------------------
# Iteration (train phase) 33/300
# Finished in : 8.416996479034424
# ------------------------------
# Iteration (train phase) 34/300
# Finished in : 8.180560827255249
# ------------------------------
# Iteration (train phase) 35/300
# Finished in : 8.635810375213623
# ------------------------------
# Iteration (train phase) 36/300
# Finished in : 8.217169284820557
# ------------------------------
# Iteration (train phase) 37/300
# Finished in : 7.879591703414917
# ------------------------------
# Iteration (train phase) 38/300
# Finished in : 8.502764463424683
# ------------------------------
# Iteration (train phase) 39/300
# Finished in : 8.372917413711548
# ------------------------------
# Iteration (train phase) 40/300
# Finished in : 8.38249659538269
# ------------------------------
# Iteration (train phase) 41/300
# Finished in : 7.903956413269043
# ------------------------------
# Iteration (train phase) 42/300
# Finished in : 7.898078203201294
# ------------------------------
# Iteration (train phase) 43/300
# Finished in : 8.173691272735596
# ------------------------------
# Iteration (train phase) 44/300
# Finished in : 8.336482286453247
# ------------------------------
# Iteration (train phase) 45/300
# Finished in : 8.45930528640747
# ------------------------------
# Iteration (train phase) 46/300
# Finished in : 8.254162073135376
# ------------------------------
# Iteration (train phase) 47/300
# Finished in : 8.76045823097229
# ------------------------------
# Iteration (train phase) 48/300
# Finished in : 9.699997663497925
# ------------------------------
# Iteration (train phase) 49/300
# Finished in : 8.95986270904541
# ------------------------------
# Iteration (train phase) 50/300
# Finished in : 9.286283016204834
# ------------------------------
# Iteration (train phase) 51/300
# Finished in : 9.36123776435852
# ------------------------------
# Iteration (train phase) 52/300
# Finished in : 10.141887426376343
# ------------------------------
# Iteration (train phase) 53/300
# Finished in : 8.381155967712402
# ------------------------------
# Iteration (train phase) 54/300
# Finished in : 9.22021770477295
# ------------------------------
# Iteration (train phase) 55/300
# Finished in : 8.004372119903564
# ------------------------------
# Iteration (train phase) 56/300
# Finished in : 9.4601731300354
# ------------------------------
# Iteration (train phase) 57/300
# Finished in : 7.615093469619751
# ------------------------------
# Iteration (train phase) 58/300
# Finished in : 8.283595561981201
# ------------------------------
# Iteration (train phase) 59/300
# Finished in : 8.241130590438843
# ------------------------------
# Iteration (train phase) 60/300
# Finished in : 8.096534252166748
# ------------------------------
# Iteration (train phase) 61/300
# Finished in : 7.97726035118103
# ------------------------------
# Iteration (train phase) 62/300
# Finished in : 8.059907913208008
# ------------------------------
# Iteration (train phase) 63/300
# Finished in : 8.00069785118103
# ------------------------------
# Iteration (train phase) 64/300
# Finished in : 8.149638891220093
# ------------------------------
# Iteration (train phase) 65/300
# Finished in : 10.032320737838745
# ------------------------------
# Iteration (train phase) 66/300
# Finished in : 8.563820362091064
# ------------------------------
# Iteration (train phase) 67/300
# Finished in : 8.243951797485352
# ------------------------------
# Iteration (train phase) 68/300
# Finished in : 8.907763957977295
# ------------------------------
# Iteration (train phase) 69/300
# Finished in : 10.332723617553711
# ------------------------------
# Iteration (train phase) 70/300
# Finished in : 8.295540809631348
# ------------------------------
# Iteration (train phase) 71/300
# Finished in : 8.767089605331421
# ------------------------------
# Iteration (train phase) 72/300
# Finished in : 8.696995496749878
# ------------------------------
# Iteration (train phase) 73/300
# Finished in : 8.83950424194336
# ------------------------------
# Iteration (train phase) 74/300
# Finished in : 8.997588396072388
# ------------------------------
# Iteration (train phase) 75/300
# Finished in : 9.134454488754272
# ------------------------------
# Iteration (train phase) 76/300
# Finished in : 8.299169301986694
# ------------------------------
# Iteration (train phase) 77/300
# Finished in : 8.790857076644897
# ------------------------------
# Iteration (train phase) 78/300
# Finished in : 9.162886619567871
# ------------------------------
# Iteration (train phase) 79/300
# Finished in : 8.641048192977905
# ------------------------------
# Iteration (train phase) 80/300
# Finished in : 8.73422646522522
# ------------------------------
# Iteration (train phase) 81/300
# Finished in : 9.050535678863525
# ------------------------------
# Iteration (train phase) 82/300
# Finished in : 9.265136480331421
# ------------------------------
# Iteration (train phase) 83/300
# Finished in : 8.095739603042603
# ------------------------------
# Iteration (train phase) 84/300
# Finished in : 8.67611312866211
# ------------------------------
# Iteration (train phase) 85/300
# Finished in : 9.107684135437012
# ------------------------------
# Iteration (train phase) 86/300
# Finished in : 9.90006971359253
# ------------------------------
# Iteration (train phase) 87/300
# Finished in : 8.059370994567871
# ------------------------------
# Iteration (train phase) 88/300
# Finished in : 7.998964786529541
# ------------------------------
# Iteration (train phase) 89/300
# Finished in : 8.277908325195312
# ------------------------------
# Iteration (train phase) 90/300
# Finished in : 8.361283779144287
# ------------------------------
# Iteration (train phase) 91/300
# Finished in : 8.081031084060669
# ------------------------------
# Iteration (train phase) 92/300
# Finished in : 8.82059121131897
# ------------------------------
# Iteration (train phase) 93/300
# Finished in : 8.32424783706665
# ------------------------------
# Iteration (train phase) 94/300
# Finished in : 8.298234462738037
# ------------------------------
# Iteration (train phase) 95/300
# Finished in : 7.900273561477661
# ------------------------------
# Iteration (train phase) 96/300
# Finished in : 7.644995450973511
# ------------------------------
# Iteration (train phase) 97/300
# Finished in : 7.893876314163208
# ------------------------------
# Iteration (train phase) 98/300
# Finished in : 8.003751993179321
# ------------------------------
# Iteration (train phase) 99/300
# Finished in : 9.433876991271973
# ------------------------------
# Iteration (train phase) 100/300
# Finished in : 8.023315191268921
# ------------------------------
# Iteration (train phase) 101/300
# Finished in : 8.094710111618042
# ------------------------------
# Iteration (train phase) 102/300
# Finished in : 8.317621231079102
# ------------------------------
# Iteration (train phase) 103/300
# Finished in : 7.899901628494263
# ------------------------------
# Iteration (train phase) 104/300
# Finished in : 8.438235759735107
# ------------------------------
# Iteration (train phase) 105/300
# Finished in : 7.9408934116363525
# ------------------------------
# Iteration (train phase) 106/300
# Finished in : 8.335671424865723
# ------------------------------
# Iteration (train phase) 107/300
# Finished in : 8.13542103767395
# ------------------------------
# Iteration (train phase) 108/300
# Finished in : 9.533118724822998
# ------------------------------
# Iteration (train phase) 109/300
# Finished in : 8.056508541107178
# ------------------------------
# Iteration (train phase) 110/300
# Finished in : 8.104464054107666
# ------------------------------
# Iteration (train phase) 111/300
# Finished in : 8.058018922805786
# ------------------------------
# Iteration (train phase) 112/300
# Finished in : 8.152339220046997
# ------------------------------
# Iteration (train phase) 113/300
# Finished in : 8.343515634536743
# ------------------------------
# Iteration (train phase) 114/300
# Finished in : 8.23304271697998
# ------------------------------
# Iteration (train phase) 115/300
# Finished in : 8.155663967132568
# ------------------------------
# Iteration (train phase) 116/300
# Finished in : 8.000771045684814
# ------------------------------
# Iteration (train phase) 117/300
# Finished in : 9.050471544265747
# ------------------------------
# Iteration (train phase) 118/300
# Finished in : 8.304193258285522
# ------------------------------
# Iteration (train phase) 119/300
# Finished in : 8.2748122215271
# ------------------------------
# Iteration (train phase) 120/300
# Finished in : 8.315216541290283
# ------------------------------
# Iteration (train phase) 121/300
# Finished in : 9.833094835281372
# ------------------------------
# Iteration (train phase) 122/300
# Finished in : 8.172434568405151
# ------------------------------
# Iteration (train phase) 123/300
# Finished in : 8.030479431152344
# ------------------------------
# Iteration (train phase) 124/300
# Finished in : 8.738386392593384
# ------------------------------
# Iteration (train phase) 125/300
# Finished in : 8.106463432312012
# ------------------------------
# Iteration (train phase) 126/300
# Finished in : 8.233254671096802
# ------------------------------
# Iteration (train phase) 127/300
# Finished in : 9.334154605865479
# ------------------------------
# Iteration (train phase) 128/300
# Finished in : 8.153179407119751
# ------------------------------
# Iteration (train phase) 129/300
# Finished in : 8.420078992843628
# ------------------------------
# Iteration (train phase) 130/300
# Finished in : 9.15568232536316
# ------------------------------
# Iteration (train phase) 131/300
# Finished in : 8.21841049194336
# ------------------------------
# Iteration (train phase) 132/300
# Finished in : 8.857876062393188
# ------------------------------
# Iteration (train phase) 133/300
# Finished in : 8.497515201568604
# ------------------------------
# Iteration (train phase) 134/300
# Finished in : 9.93077301979065
# ------------------------------
# Iteration (train phase) 135/300
# Finished in : 8.35341763496399
# ------------------------------
# Iteration (train phase) 136/300
# Finished in : 8.338930606842041
# ------------------------------
# Iteration (train phase) 137/300
# Finished in : 7.9852259159088135
# ------------------------------
# Iteration (train phase) 138/300
# Finished in : 7.962252378463745
# ------------------------------
# Iteration (train phase) 139/300
# Finished in : 8.280373096466064
# ------------------------------
# Iteration (train phase) 140/300
# Finished in : 8.194703817367554
# ------------------------------
# Iteration (train phase) 141/300
# Finished in : 8.153154850006104
# ------------------------------
# Iteration (train phase) 142/300
# Finished in : 8.459986686706543
# ------------------------------
# Iteration (train phase) 143/300
# Finished in : 8.820868730545044
# ------------------------------
# Iteration (train phase) 144/300
# Finished in : 8.640688180923462
# ------------------------------
# Iteration (train phase) 145/300
# Finished in : 8.540639877319336
# ------------------------------
# Iteration (train phase) 146/300
# Finished in : 8.01247525215149
# ------------------------------
# Iteration (train phase) 147/300
# Finished in : 10.162243843078613
# ------------------------------
# Iteration (train phase) 148/300
# Finished in : 8.084211826324463
# ------------------------------
# Iteration (train phase) 149/300
# Finished in : 8.213543891906738
# ------------------------------
# Iteration (train phase) 150/300
# Finished in : 8.81402850151062
# ------------------------------
# Iteration (train phase) 151/300
# Finished in : 8.576328754425049
# ------------------------------
# Iteration (train phase) 152/300
# Finished in : 8.096669912338257
# ------------------------------
# Iteration (train phase) 153/300
# Finished in : 7.897547483444214
# ------------------------------
# Iteration (train phase) 154/300
# Finished in : 8.078608512878418
# ------------------------------
# Iteration (train phase) 155/300
# Finished in : 8.157020568847656
# ------------------------------
# Iteration (train phase) 156/300
# Finished in : 8.779609441757202
# ------------------------------
# Iteration (train phase) 157/300
# Finished in : 7.937540292739868
# ------------------------------
# Iteration (train phase) 158/300
# Finished in : 7.867266893386841
# ------------------------------
# Iteration (train phase) 159/300
# Finished in : 8.630439043045044
# ------------------------------
# Iteration (train phase) 160/300
# Finished in : 8.849238395690918
# ------------------------------
# Iteration (train phase) 161/300
# Finished in : 7.6793012619018555
# ------------------------------
# Iteration (train phase) 162/300
# Finished in : 7.943482398986816
# ------------------------------
# Iteration (train phase) 163/300
# Finished in : 7.817438840866089
# ------------------------------
# Iteration (train phase) 164/300
# Finished in : 8.319974422454834
# ------------------------------
# Iteration (train phase) 165/300
# Finished in : 8.637115240097046
# ------------------------------
# Iteration (train phase) 166/300
# Finished in : 7.972647190093994
# ------------------------------
# Iteration (train phase) 167/300
# Finished in : 8.4792959690094
# ------------------------------
# Iteration (train phase) 168/300
# Finished in : 8.01951289176941
# ------------------------------
# Iteration (train phase) 169/300
# Finished in : 9.733069658279419
# ------------------------------
# Iteration (train phase) 170/300
# Finished in : 8.569430112838745
# ------------------------------
# Iteration (train phase) 171/300
# Finished in : 8.512185096740723
# ------------------------------
# Iteration (train phase) 172/300
# Finished in : 9.138145685195923
# ------------------------------
# Iteration (train phase) 173/300
# Finished in : 8.85788893699646
# ------------------------------
# Iteration (train phase) 174/300
# Finished in : 8.973753213882446
# ------------------------------
# Iteration (train phase) 175/300
# Finished in : 8.573554277420044
# ------------------------------
# Iteration (train phase) 176/300
# Finished in : 8.53183650970459
# ------------------------------
# Iteration (train phase) 177/300
# Finished in : 7.9365010261535645
# ------------------------------
# Iteration (train phase) 178/300
# Finished in : 8.560436725616455
# ------------------------------
# Iteration (train phase) 179/300
# Finished in : 8.139034271240234
# ------------------------------
# Iteration (train phase) 180/300
# Finished in : 8.259228944778442
# ------------------------------
# Iteration (train phase) 181/300
# Finished in : 8.561070680618286
# ------------------------------
# Iteration (train phase) 182/300
# Finished in : 9.70615530014038
# ------------------------------
# Iteration (train phase) 183/300
# Finished in : 8.620060443878174
# ------------------------------
# Iteration (train phase) 184/300
# Finished in : 8.50276255607605
# ------------------------------
# Iteration (train phase) 185/300
# Finished in : 8.182881593704224
# ------------------------------
# Iteration (train phase) 186/300
# Finished in : 8.138694763183594
# ------------------------------
# Iteration (train phase) 187/300
# Finished in : 8.378981590270996
# ------------------------------
# Iteration (train phase) 188/300
# Finished in : 8.441991567611694
# ------------------------------
# Iteration (train phase) 189/300
# Finished in : 7.7838521003723145
# ------------------------------
# Iteration (train phase) 190/300
# Finished in : 8.101059198379517
# ------------------------------
# Iteration (train phase) 191/300
# Finished in : 7.961369037628174
# ------------------------------
# Iteration (train phase) 192/300
# Finished in : 7.913283586502075
# ------------------------------
# Iteration (train phase) 193/300
# Finished in : 8.155797004699707
# ------------------------------
# Iteration (train phase) 194/300
# Finished in : 8.67830491065979
# ------------------------------
# Iteration (train phase) 195/300
# Finished in : 10.144280433654785
# ------------------------------
# Iteration (train phase) 196/300
# Finished in : 8.479824781417847
# ------------------------------
# Iteration (train phase) 197/300
# Finished in : 8.152695894241333
# ------------------------------
# Iteration (train phase) 198/300
# Finished in : 8.840245485305786
# ------------------------------
# Iteration (train phase) 199/300
# Finished in : 8.712790727615356
# ------------------------------
# Iteration (train phase) 200/300
# Finished in : 8.738402843475342
# ------------------------------
# Iteration (train phase) 201/300
# Finished in : 9.039096593856812
# ------------------------------
# Iteration (train phase) 202/300
# Finished in : 8.822091102600098
# ------------------------------
# Iteration (train phase) 203/300
# Finished in : 8.817781925201416
# ------------------------------
# Iteration (train phase) 204/300
# Finished in : 8.576414823532104
# ------------------------------
# Iteration (train phase) 205/300
# Finished in : 8.624199867248535
# ------------------------------
# Iteration (train phase) 206/300
# Finished in : 8.497882843017578
# ------------------------------
# Iteration (train phase) 207/300
# Finished in : 8.64108157157898
# ------------------------------
# Iteration (train phase) 208/300
# Finished in : 9.420250177383423
# ------------------------------
# Iteration (train phase) 209/300
# Finished in : 8.479743242263794
# ------------------------------
# Iteration (train phase) 210/300
# Finished in : 8.261536359786987
# ------------------------------
# Iteration (train phase) 211/300
# Finished in : 8.176798820495605
# ------------------------------
# Iteration (train phase) 212/300
# Finished in : 8.73337459564209
# ------------------------------
# Iteration (train phase) 213/300
# Finished in : 8.540710687637329
# ------------------------------
# Iteration (train phase) 214/300
# Finished in : 7.977907419204712
# ------------------------------
# Iteration (train phase) 215/300
# Finished in : 8.177788019180298
# ------------------------------
# Iteration (train phase) 216/300
# Finished in : 7.877224922180176
# ------------------------------
# Iteration (train phase) 217/300
# Finished in : 9.0808265209198
# ------------------------------
# Iteration (train phase) 218/300
# Finished in : 7.821589469909668
# ------------------------------
# Iteration (train phase) 219/300
# Finished in : 8.073693752288818
# ------------------------------
# Iteration (train phase) 220/300
# Finished in : 7.563438415527344
# ------------------------------
# Iteration (train phase) 221/300
# Finished in : 8.357548236846924
# ------------------------------
# Iteration (train phase) 222/300
# Finished in : 8.643638849258423
# ------------------------------
# Iteration (train phase) 223/300
# Finished in : 8.167162656784058
# ------------------------------
# Iteration (train phase) 224/300
# Finished in : 8.179572343826294
# ------------------------------
# Iteration (train phase) 225/300
# Finished in : 8.296172618865967
# ------------------------------
# Iteration (train phase) 226/300
# Finished in : 9.646333456039429
# ------------------------------
# Iteration (train phase) 227/300
# Finished in : 8.21514081954956
# ------------------------------
# Iteration (train phase) 228/300
# Finished in : 8.078651666641235
# ------------------------------
# Iteration (train phase) 229/300
# Finished in : 8.259104490280151
# ------------------------------
# Iteration (train phase) 230/300
# Finished in : 7.995190620422363
# ------------------------------
# Iteration (train phase) 231/300
# Finished in : 8.456825971603394
# ------------------------------
# Iteration (train phase) 232/300
# Finished in : 7.879404306411743
# ------------------------------
# Iteration (train phase) 233/300
# Finished in : 7.5148773193359375
# ------------------------------
# Iteration (train phase) 234/300
# Finished in : 7.778338193893433
# ------------------------------
# Iteration (train phase) 235/300
# Finished in : 9.135774850845337
# ------------------------------
# Iteration (train phase) 236/300
# Finished in : 8.318577289581299
# ------------------------------
# Iteration (train phase) 237/300
# Finished in : 7.622892618179321
# ------------------------------
# Iteration (train phase) 238/300
# Finished in : 7.81614875793457
# ------------------------------
# Iteration (train phase) 239/300
# Finished in : 7.545875787734985
# ------------------------------
# Iteration (train phase) 240/300
# Finished in : 8.056182622909546
# ------------------------------
# Iteration (train phase) 241/300
# Finished in : 8.141145944595337
# ------------------------------
# Iteration (train phase) 242/300
# Finished in : 8.551568984985352
# ------------------------------
# Iteration (train phase) 243/300
# Finished in : 8.004746913909912
# ------------------------------
# Iteration (train phase) 244/300
# Finished in : 9.562860012054443
# ------------------------------
# Iteration (train phase) 245/300
# Finished in : 7.975633382797241
# ------------------------------
# Iteration (train phase) 246/300
# Finished in : 8.301602363586426
# ------------------------------
# Iteration (train phase) 247/300
# Finished in : 7.760605096817017
# ------------------------------
# Iteration (train phase) 248/300
# Finished in : 8.240175485610962
# ------------------------------
# Iteration (train phase) 249/300
# Finished in : 7.917098045349121
# ------------------------------
# Iteration (train phase) 250/300
# Finished in : 7.938403129577637
# ------------------------------
# Iteration (train phase) 251/300
# Finished in : 7.732727289199829
# ------------------------------
# Iteration (train phase) 252/300
# Finished in : 7.861936569213867
# ------------------------------
# Iteration (train phase) 253/300
# Finished in : 7.897204399108887
# ------------------------------
# Iteration (train phase) 254/300
# Finished in : 8.481046915054321
# ------------------------------
# Iteration (train phase) 255/300
# Finished in : 8.591724395751953
# ------------------------------
# Iteration (train phase) 256/300
# Finished in : 7.834249019622803
# ------------------------------
# Iteration (train phase) 257/300
# Finished in : 9.686177492141724
# ------------------------------
# Iteration (train phase) 258/300
# Finished in : 8.119178295135498
# ------------------------------
# Iteration (train phase) 259/300
# Finished in : 7.680412769317627
# ------------------------------
# Iteration (train phase) 260/300
# Finished in : 8.071834564208984
# ------------------------------
# Iteration (train phase) 261/300
# Finished in : 8.05818510055542
# ------------------------------
# Iteration (train phase) 262/300
# Finished in : 8.056139945983887
# ------------------------------
# Iteration (train phase) 263/300
# Finished in : 8.199326992034912
# ------------------------------
# Iteration (train phase) 264/300
# Finished in : 8.175578832626343
# ------------------------------
# Iteration (train phase) 265/300
# Finished in : 7.97786021232605
# ------------------------------
# Iteration (train phase) 266/300
# Finished in : 8.321760177612305
# ------------------------------
# Iteration (train phase) 267/300
# Finished in : 8.055643081665039
# ------------------------------
# Iteration (train phase) 268/300
# Finished in : 8.256603240966797
# ------------------------------
# Iteration (train phase) 269/300
# Finished in : 8.073024988174438
# ------------------------------
# Iteration (train phase) 270/300
# Finished in : 9.67663836479187
# ------------------------------
# Iteration (train phase) 271/300
# Finished in : 8.272470712661743
# ------------------------------
# Iteration (train phase) 272/300
# Finished in : 8.186366081237793
# ------------------------------
# Iteration (train phase) 273/300
# Finished in : 7.997164964675903
# ------------------------------
# Iteration (train phase) 274/300
# Finished in : 8.335646390914917
# ------------------------------
# Iteration (train phase) 275/300
# Finished in : 8.141430854797363
# ------------------------------
# Iteration (train phase) 276/300
# Finished in : 7.762267351150513
# ------------------------------
# Iteration (train phase) 277/300
# Finished in : 8.230897188186646
# ------------------------------
# Iteration (train phase) 278/300
# Finished in : 8.679669618606567
# ------------------------------
# Iteration (train phase) 279/300
# Finished in : 9.517808437347412
# ------------------------------
# Iteration (train phase) 280/300
# Finished in : 8.167745590209961
# ------------------------------
# Iteration (train phase) 281/300
# Finished in : 8.237133502960205
# ------------------------------
# Iteration (train phase) 282/300
# Finished in : 7.938558578491211
# ------------------------------
# Iteration (train phase) 283/300
# Finished in : 7.8164122104644775
# ------------------------------
# Iteration (train phase) 284/300
# Finished in : 8.077150106430054
# ------------------------------
# Iteration (train phase) 285/300
# Finished in : 7.821997165679932
# ------------------------------
# Iteration (train phase) 286/300
# Finished in : 8.196568965911865
# ------------------------------
# Iteration (train phase) 287/300
# Finished in : 8.019383430480957
# ------------------------------
# Iteration (train phase) 288/300
# Finished in : 9.302819728851318
# ------------------------------
# Iteration (train phase) 289/300
# Finished in : 7.637838125228882
# ------------------------------
# Iteration (train phase) 290/300
# Finished in : 7.979389190673828
# ------------------------------
# Iteration (train phase) 291/300
# Finished in : 7.517646551132202
# ------------------------------
# Iteration (train phase) 292/300
# Finished in : 8.056117296218872
# ------------------------------
# Iteration (train phase) 293/300
# Finished in : 8.00069522857666
# ------------------------------
# Iteration (train phase) 294/300
# Finished in : 7.797907829284668
# ------------------------------
# Iteration (train phase) 295/300
# Finished in : 8.033050775527954
# ------------------------------
# Iteration (train phase) 296/300
# Finished in : 8.125929832458496
# ------------------------------
# Iteration (train phase) 297/300
# Finished in : 9.457231283187866
# ------------------------------
# Iteration (train phase) 298/300
# Finished in : 8.55920958518982
# ------------------------------
# Iteration (train phase) 299/300
# Finished in : 8.495794534683228
# ------------------------------
# Iteration (train phase) 300/300
# Finished in : 7.976560592651367
# ------------------------------
# Iteration (validation phase) 1/100
# ------------------------------
# Iteration (validation phase) 2/100
# ------------------------------
# Iteration (validation phase) 3/100
# ------------------------------
# Iteration (validation phase) 4/100
# ------------------------------
# Iteration (validation phase) 5/100
# ------------------------------
# Iteration (validation phase) 6/100
# ------------------------------
# Iteration (validation phase) 7/100
# ------------------------------
# Iteration (validation phase) 8/100
# ------------------------------
# Iteration (validation phase) 9/100
# ------------------------------
# Iteration (validation phase) 10/100
# ------------------------------
# Iteration (validation phase) 11/100
# ------------------------------
# Iteration (validation phase) 12/100
# ------------------------------
# Iteration (validation phase) 13/100
# ------------------------------
# Iteration (validation phase) 14/100
# ------------------------------
# Iteration (validation phase) 15/100
# ------------------------------
# Iteration (validation phase) 16/100
# ------------------------------
# Iteration (validation phase) 17/100
# ------------------------------
# Iteration (validation phase) 18/100
# ------------------------------
# Iteration (validation phase) 19/100
# ------------------------------
# Iteration (validation phase) 20/100
# ------------------------------
# Iteration (validation phase) 21/100
# ------------------------------
# Iteration (validation phase) 22/100
# ------------------------------
# Iteration (validation phase) 23/100
# ------------------------------
# Iteration (validation phase) 24/100
# ------------------------------
# Iteration (validation phase) 25/100
# ------------------------------
# Iteration (validation phase) 26/100
# ------------------------------
# Iteration (validation phase) 27/100
# ------------------------------
# Iteration (validation phase) 28/100
# ------------------------------
# Iteration (validation phase) 29/100
# ------------------------------
# Iteration (validation phase) 30/100
# ------------------------------
# Iteration (validation phase) 31/100
# ------------------------------
# Iteration (validation phase) 32/100
# ------------------------------
# Iteration (validation phase) 33/100
# ------------------------------
# Iteration (validation phase) 34/100
# ------------------------------
# Iteration (validation phase) 35/100
# ------------------------------
# Iteration (validation phase) 36/100
# ------------------------------
# Iteration (validation phase) 37/100
# ------------------------------
# Iteration (validation phase) 38/100
# ------------------------------
# Iteration (validation phase) 39/100
# ------------------------------
# Iteration (validation phase) 40/100
# ------------------------------
# Iteration (validation phase) 41/100
# ------------------------------
# Iteration (validation phase) 42/100
# ------------------------------
# Iteration (validation phase) 43/100
# ------------------------------
# Iteration (validation phase) 44/100
# ------------------------------
# Iteration (validation phase) 45/100
# ------------------------------
# Iteration (validation phase) 46/100
# ------------------------------
# Iteration (validation phase) 47/100
# ------------------------------
# Iteration (validation phase) 48/100
# ------------------------------
# Iteration (validation phase) 49/100
# ------------------------------
# Iteration (validation phase) 50/100
# ------------------------------
# Iteration (validation phase) 51/100
# ------------------------------
# Iteration (validation phase) 52/100
# ------------------------------
# Iteration (validation phase) 53/100
# ------------------------------
# Iteration (validation phase) 54/100
# ------------------------------
# Iteration (validation phase) 55/100
# ------------------------------
# Iteration (validation phase) 56/100
# ------------------------------
# Iteration (validation phase) 57/100
# ------------------------------
# Iteration (validation phase) 58/100
# ------------------------------
# Iteration (validation phase) 59/100
# ------------------------------
# Iteration (validation phase) 60/100
# ------------------------------
# Iteration (validation phase) 61/100
# ------------------------------
# Iteration (validation phase) 62/100
# ------------------------------
# Iteration (validation phase) 63/100
# ------------------------------
# Iteration (validation phase) 64/100
# ------------------------------
# Iteration (validation phase) 65/100
# ------------------------------
# Iteration (validation phase) 66/100
# ------------------------------
# Iteration (validation phase) 67/100
# ------------------------------
# Iteration (validation phase) 68/100
# ------------------------------
# Iteration (validation phase) 69/100
# ------------------------------
# Iteration (validation phase) 70/100
# ------------------------------
# Iteration (validation phase) 71/100
# ------------------------------
# Iteration (validation phase) 72/100
# ------------------------------
# Iteration (validation phase) 73/100
# ------------------------------
# Iteration (validation phase) 74/100
# ------------------------------
# Iteration (validation phase) 75/100
# ------------------------------
# Iteration (validation phase) 76/100
# ------------------------------
# Iteration (validation phase) 77/100
# ------------------------------
# Iteration (validation phase) 78/100
# ------------------------------
# Iteration (validation phase) 79/100
# ------------------------------
# Iteration (validation phase) 80/100
# ------------------------------
# Iteration (validation phase) 81/100
# ------------------------------
# Iteration (validation phase) 82/100
# ------------------------------
# Iteration (validation phase) 83/100
# ------------------------------
# Iteration (validation phase) 84/100
# ------------------------------
# Iteration (validation phase) 85/100
# ------------------------------
# Iteration (validation phase) 86/100
# ------------------------------
# Iteration (validation phase) 87/100
# ------------------------------
# Iteration (validation phase) 88/100
# ------------------------------
# Iteration (validation phase) 89/100
# ------------------------------
# Iteration (validation phase) 90/100
# ------------------------------
# Iteration (validation phase) 91/100
# ------------------------------
# Iteration (validation phase) 92/100
# ------------------------------
# Iteration (validation phase) 93/100
# ------------------------------
# Iteration (validation phase) 94/100
# ------------------------------
# Iteration (validation phase) 95/100
# ------------------------------
# Iteration (validation phase) 96/100
# ------------------------------
# Iteration (validation phase) 97/100
# ------------------------------
# Iteration (validation phase) 98/100
# ------------------------------
# Iteration (validation phase) 99/100
# ------------------------------
# Iteration (validation phase) 100/100
# Epoch 1, Accuracy: 0.9948
# All finished in : 5675.019272565842

# %%
n_epochs = 1
loss_list = []
accuracy_list = []
accuracy = 0
correct = 0
N_test = len(validation_dataset)
N_train = len(train_dataset)
start_time = time.time()
#n_epochs
batch_size = 100
print("Number of items in training set : ", N_train)
print("Number of items in testing set : ", N_test)

running_loss = 0
start_time = time.time()
for epoch in range(n_epochs):
    for i, (x, y) in enumerate(train_loader):        
        print('-' * 30)
        print('Iteration (train phase) {}/{}'.format(i+1, int(N_train/batch_size)))
        i_start_time = time.time()
        
            
        # set model to train 
        model.train() 
        
        # clear gradient 
        optimizer.zero_grad()
     
        # make a prediction 
        z = model(x)
   
        # calculate loss 
        loss = criterion(z, y) 
        # loss.requires_grad = True
    
        # calculate gradients of parameters 
        loss.backward()
        
        # update parameters 
        optimizer.step()
        
        loss_list.append(loss.data)
        print("Finished in {} (s)".format(time.time()-i_start_time))
    # end for
        
    correct=0
    for i, (x_test, y_test) in enumerate(validation_loader):
        print('-' * 30)
        print('Iteration (validation phase) {}/{}'.format(i+1, int(N_test/batch_size)))
        i_start_time = time.time()
        
        # set model to eval 
        model.eval()
       
        # make a prediction 
        z = model(x_test)
        
        # find max 
        _, yhat = torch.max(z.data, 1)
       
       
        #Calculate misclassified  samples in mini-batch 
        #hint +=(yhat==y_test).sum().item()
        correct += (yhat==y_test).sum().item()  
        
        print("Finished in {} (s)".format(time.time()-i_start_time))
    # end for
    
    accuracy=correct/N_test
    print("Epoch %d - accuracy: %.3f" % (epoch+1, accuracy))
    
    accuracy_list.append(accuracy)
    print("-" * 72)
    
    # Save model
    model_file_path = model_path + "resnet18_trained_model_epoch_{}.pth".format(epoch+1)
    torch.save(model.state_dict(), model_file_path)
    
    # Duration for epoch
    print("Finished epoch {} in {} (s).".format(epoch+1, time.time()-start_time))
# end for
# Out:
# Number of items in training set :  30000
# Number of items in testing set :  10000
# ------------------------------
# Iteration (train phase) 1/300
# Finished in 9.880710124969482 (s)
# ------------------------------
# Iteration (train phase) 2/300
# Finished in 10.076944589614868 (s)
# ------------------------------
# Iteration (train phase) 3/300
# Finished in 9.677776575088501 (s)
# ------------------------------
# Iteration (train phase) 4/300
# Finished in 9.843631029129028 (s)
# ------------------------------
# Iteration (train phase) 5/300
# Finished in 9.742504835128784 (s)
# ------------------------------
# Iteration (train phase) 6/300
# Finished in 10.158768892288208 (s)
# ------------------------------
# Iteration (train phase) 7/300
# Finished in 9.581048250198364 (s)
# ------------------------------
# Iteration (train phase) 8/300
# Finished in 9.219329118728638 (s)
# ------------------------------
# Iteration (train phase) 9/300
# Finished in 9.833698749542236 (s)
# ------------------------------
# Iteration (train phase) 10/300
# Finished in 9.93276333808899 (s)
# ------------------------------
# Iteration (train phase) 11/300
# Finished in 9.581640720367432 (s)
# ------------------------------
# Iteration (train phase) 12/300
# Finished in 9.527255535125732 (s)
# ------------------------------
# Iteration (train phase) 13/300
# Finished in 9.761687755584717 (s)
# ------------------------------
# Iteration (train phase) 14/300
# Finished in 9.918259382247925 (s)
# ------------------------------
# Iteration (train phase) 15/300
# Finished in 10.23673939704895 (s)
# ------------------------------
# Iteration (train phase) 16/300
# Finished in 10.093585968017578 (s)
# ------------------------------
# Iteration (train phase) 17/300
# Finished in 10.042244672775269 (s)
# ------------------------------
# Iteration (train phase) 18/300
# Finished in 10.246570110321045 (s)
# ------------------------------
# Iteration (train phase) 19/300
# Finished in 9.651966571807861 (s)
# ------------------------------
# Iteration (train phase) 20/300
# Finished in 9.941801071166992 (s)
# ------------------------------
# Iteration (train phase) 21/300
# Finished in 9.883344411849976 (s)
# ------------------------------
# Iteration (train phase) 22/300
# Finished in 9.86394190788269 (s)
# ------------------------------
# Iteration (train phase) 23/300
# Finished in 9.78016448020935 (s)
# ------------------------------
# Iteration (train phase) 24/300
# Finished in 10.096689224243164 (s)
# ------------------------------
# Iteration (train phase) 25/300
# Finished in 9.314269781112671 (s)
# ------------------------------
# Iteration (train phase) 26/300
# Finished in 9.264503240585327 (s)
# ------------------------------
# Iteration (train phase) 27/300
# Finished in 9.725421667098999 (s)
# ------------------------------
# Iteration (train phase) 28/300
# Finished in 9.675915479660034 (s)
# ------------------------------
# Iteration (train phase) 29/300
# Finished in 10.013582944869995 (s)
# ------------------------------
# Iteration (train phase) 30/300
# Finished in 9.478079795837402 (s)
# ------------------------------
# Iteration (train phase) 31/300
# Finished in 9.611156702041626 (s)
# ------------------------------
# Iteration (train phase) 32/300
# Finished in 9.33702564239502 (s)
# ------------------------------
# Iteration (train phase) 33/300
# Finished in 9.341188669204712 (s)
# ------------------------------
# Iteration (train phase) 34/300
# Finished in 9.38155460357666 (s)
# ------------------------------
# Iteration (train phase) 35/300
# Finished in 9.401233434677124 (s)
# ------------------------------
# Iteration (train phase) 36/300
# Finished in 10.075354099273682 (s)
# ------------------------------
# Iteration (train phase) 37/300
# Finished in 9.56435751914978 (s)
# ------------------------------
# Iteration (train phase) 38/300
# Finished in 9.533690214157104 (s)
# ------------------------------
# Iteration (train phase) 39/300
# Finished in 10.54018259048462 (s)
# ------------------------------
# Iteration (train phase) 40/300
# Finished in 9.372752666473389 (s)
# ------------------------------
# Iteration (train phase) 41/300
# Finished in 9.541151523590088 (s)
# ------------------------------
# Iteration (train phase) 42/300
# Finished in 9.73884391784668 (s)
# ------------------------------
# Iteration (train phase) 43/300
# Finished in 9.633404016494751 (s)
# ------------------------------
# Iteration (train phase) 44/300
# Finished in 9.994435787200928 (s)
# ------------------------------
# Iteration (train phase) 45/300
# Finished in 9.603324890136719 (s)
# ------------------------------
# Iteration (train phase) 46/300
# Finished in 9.33199429512024 (s)
# ------------------------------
# Iteration (train phase) 47/300
# Finished in 9.713533401489258 (s)
# ------------------------------
# Iteration (train phase) 48/300
# Finished in 9.872866868972778 (s)
# ------------------------------
# Iteration (train phase) 49/300
# Finished in 9.445462226867676 (s)
# ------------------------------
# Iteration (train phase) 50/300
# Finished in 9.652716398239136 (s)
# ------------------------------
# Iteration (train phase) 51/300
# Finished in 9.582519769668579 (s)
# ------------------------------
# Iteration (train phase) 52/300
# Finished in 9.455203294754028 (s)
# ------------------------------
# Iteration (train phase) 53/300
# Finished in 9.713465213775635 (s)
# ------------------------------
# Iteration (train phase) 54/300
# Finished in 9.382578134536743 (s)
# ------------------------------
# Iteration (train phase) 55/300
# Finished in 9.793012142181396 (s)
# ------------------------------
# Iteration (train phase) 56/300
# Finished in 9.815560102462769 (s)
# ------------------------------
# Iteration (train phase) 57/300
# Finished in 9.572282791137695 (s)
# ------------------------------
# Iteration (train phase) 58/300
# Finished in 9.832287788391113 (s)
# ------------------------------
# Iteration (train phase) 59/300
# Finished in 9.978024005889893 (s)
# ------------------------------
# Iteration (train phase) 60/300
# Finished in 9.738579750061035 (s)
# ------------------------------
# Iteration (train phase) 61/300
# Finished in 9.45213508605957 (s)
# ------------------------------
# Iteration (train phase) 62/300
# Finished in 9.415501594543457 (s)
# ------------------------------
# Iteration (train phase) 63/300
# Finished in 9.952342748641968 (s)
# ------------------------------
# Iteration (train phase) 64/300
# Finished in 9.719528913497925 (s)
# ------------------------------
# Iteration (train phase) 65/300
# Finished in 9.698606967926025 (s)
# ------------------------------
# Iteration (train phase) 66/300
# Finished in 9.033553123474121 (s)
# ------------------------------
# Iteration (train phase) 67/300
# Finished in 9.162848472595215 (s)
# ------------------------------
# Iteration (train phase) 68/300
# Finished in 9.04617977142334 (s)
# ------------------------------
# Iteration (train phase) 69/300
# Finished in 9.400968790054321 (s)
# ------------------------------
# Iteration (train phase) 70/300
# Finished in 9.042068719863892 (s)
# ------------------------------
# Iteration (train phase) 71/300
# Finished in 9.294007301330566 (s)
# ------------------------------
# Iteration (train phase) 72/300
# Finished in 9.573405504226685 (s)
# ------------------------------
# Iteration (train phase) 73/300
# Finished in 9.677417278289795 (s)
# ------------------------------
# Iteration (train phase) 74/300
# Finished in 9.436573028564453 (s)
# ------------------------------
# Iteration (train phase) 75/300
# Finished in 9.506715536117554 (s)
# ------------------------------
# Iteration (train phase) 76/300
# Finished in 9.675733804702759 (s)
# ------------------------------
# Iteration (train phase) 77/300
# Finished in 9.74210786819458 (s)
# ------------------------------
# Iteration (train phase) 78/300
# Finished in 9.217646360397339 (s)
# ------------------------------
# Iteration (train phase) 79/300
# Finished in 9.300493955612183 (s)
# ------------------------------
# Iteration (train phase) 80/300
# Finished in 9.60354208946228 (s)
# ------------------------------
# Iteration (train phase) 81/300
# Finished in 9.591370820999146 (s)
# ------------------------------
# Iteration (train phase) 82/300
# Finished in 12.260158777236938 (s)
# ------------------------------
# Iteration (train phase) 83/300
# Finished in 9.894095659255981 (s)
# ------------------------------
# Iteration (train phase) 84/300
# Finished in 9.703399419784546 (s)
# ------------------------------
# Iteration (train phase) 85/300
# Finished in 9.667704343795776 (s)
# ------------------------------
# Iteration (train phase) 86/300
# Finished in 10.23655080795288 (s)
# ------------------------------
# Iteration (train phase) 87/300
# Finished in 9.139531373977661 (s)
# ------------------------------
# Iteration (train phase) 88/300
# Finished in 9.095648527145386 (s)
# ------------------------------
# Iteration (train phase) 89/300
# Finished in 9.632452726364136 (s)
# ------------------------------
# Iteration (train phase) 90/300
# Finished in 9.503731489181519 (s)
# ------------------------------
# Iteration (train phase) 91/300
# Finished in 9.278684854507446 (s)
# ------------------------------
# Iteration (train phase) 92/300
# Finished in 9.519825220108032 (s)
# ------------------------------
# Iteration (train phase) 93/300
# Finished in 9.899678707122803 (s)
# ------------------------------
# Iteration (train phase) 94/300
# Finished in 9.919801235198975 (s)
# ------------------------------
# Iteration (train phase) 95/300
# Finished in 10.280406475067139 (s)
# ------------------------------
# Iteration (train phase) 96/300
# Finished in 10.981860876083374 (s)
# ------------------------------
# Iteration (train phase) 97/300
# Finished in 10.053458452224731 (s)
# ------------------------------
# Iteration (train phase) 98/300
# Finished in 11.711915016174316 (s)
# ------------------------------
# Iteration (train phase) 99/300
# Finished in 10.257767677307129 (s)
# ------------------------------
# Iteration (train phase) 100/300
# Finished in 9.812944889068604 (s)
# ------------------------------
# Iteration (train phase) 101/300
# Finished in 9.914900541305542 (s)
# ------------------------------
# Iteration (train phase) 102/300
# Finished in 11.43489670753479 (s)
# ------------------------------
# Iteration (train phase) 103/300
# Finished in 10.972795009613037 (s)
# ------------------------------
# Iteration (train phase) 104/300
# Finished in 10.040639400482178 (s)
# ------------------------------
# Iteration (train phase) 105/300
# Finished in 9.9986412525177 (s)
# ------------------------------
# Iteration (train phase) 106/300
# Finished in 9.939759731292725 (s)
# ------------------------------
# Iteration (train phase) 107/300
# Finished in 9.813308954238892 (s)
# ------------------------------
# Iteration (train phase) 108/300
# Finished in 9.556415557861328 (s)
# ------------------------------
# Iteration (train phase) 109/300
# Finished in 9.560713291168213 (s)
# ------------------------------
# Iteration (train phase) 110/300
# Finished in 10.187726974487305 (s)
# ------------------------------
# Iteration (train phase) 111/300
# Finished in 9.57160758972168 (s)
# ------------------------------
# Iteration (train phase) 112/300
# Finished in 9.514554500579834 (s)
# ------------------------------
# Iteration (train phase) 113/300
# Finished in 10.205938577651978 (s)
# ------------------------------
# Iteration (train phase) 114/300
# Finished in 9.913992166519165 (s)
# ------------------------------
# Iteration (train phase) 115/300
# Finished in 9.616370916366577 (s)
# ------------------------------
# Iteration (train phase) 116/300
# Finished in 9.38112998008728 (s)
# ------------------------------
# Iteration (train phase) 117/300
# Finished in 10.22408938407898 (s)
# ------------------------------
# Iteration (train phase) 118/300
# Finished in 9.467926740646362 (s)
# ------------------------------
# Iteration (train phase) 119/300
# Finished in 9.783339738845825 (s)
# ------------------------------
# Iteration (train phase) 120/300
# Finished in 9.71769118309021 (s)
# ------------------------------
# Iteration (train phase) 121/300
# Finished in 9.490961790084839 (s)
# ------------------------------
# Iteration (train phase) 122/300
# Finished in 9.411507606506348 (s)
# ------------------------------
# Iteration (train phase) 123/300
# Finished in 10.438130378723145 (s)
# ------------------------------
# Iteration (train phase) 124/300
# Finished in 9.71973180770874 (s)
# ------------------------------
# Iteration (train phase) 125/300
# Finished in 9.599794626235962 (s)
# ------------------------------
# Iteration (train phase) 126/300
# Finished in 9.732325077056885 (s)
# ------------------------------
# Iteration (train phase) 127/300
# Finished in 9.500384330749512 (s)
# ------------------------------
# Iteration (train phase) 128/300
# Finished in 9.699605464935303 (s)
# ------------------------------
# Iteration (train phase) 129/300
# Finished in 9.560188293457031 (s)
# ------------------------------
# Iteration (train phase) 130/300
# Finished in 9.101853847503662 (s)
# ------------------------------
# Iteration (train phase) 131/300
# Finished in 9.383127689361572 (s)
# ------------------------------
# Iteration (train phase) 132/300
# Finished in 9.67750883102417 (s)
# ------------------------------
# Iteration (train phase) 133/300
# Finished in 9.995465517044067 (s)
# ------------------------------
# Iteration (train phase) 134/300
# Finished in 9.73891568183899 (s)
# ------------------------------
# Iteration (train phase) 135/300
# Finished in 11.142813205718994 (s)
# ------------------------------
# Iteration (train phase) 136/300
# Finished in 10.05054259300232 (s)
# ------------------------------
# Iteration (train phase) 137/300
# Finished in 9.681884527206421 (s)
# ------------------------------
# Iteration (train phase) 138/300
# Finished in 9.565930366516113 (s)
# ------------------------------
# Iteration (train phase) 139/300
# Finished in 11.750424146652222 (s)
# ------------------------------
# Iteration (train phase) 140/300
# Finished in 10.215866565704346 (s)
# ------------------------------
# Iteration (train phase) 141/300
# Finished in 9.476800918579102 (s)
# ------------------------------
# Iteration (train phase) 142/300
# Finished in 9.403078317642212 (s)
# ------------------------------
# Iteration (train phase) 143/300
# Finished in 10.622846841812134 (s)
# ------------------------------
# Iteration (train phase) 144/300
# Finished in 9.779237985610962 (s)
# ------------------------------
# Iteration (train phase) 145/300
# Finished in 9.511593580245972 (s)
# ------------------------------
# Iteration (train phase) 146/300
# Finished in 9.731370449066162 (s)
# ------------------------------
# Iteration (train phase) 147/300
# Finished in 10.13515019416809 (s)
# ------------------------------
# Iteration (train phase) 148/300
# Finished in 9.958456754684448 (s)
# ------------------------------
# Iteration (train phase) 149/300
# Finished in 9.831006288528442 (s)
# ------------------------------
# Iteration (train phase) 150/300
# Finished in 9.479135513305664 (s)
# ------------------------------
# Iteration (train phase) 151/300
# Finished in 9.692139148712158 (s)
# ------------------------------
# Iteration (train phase) 152/300
# Finished in 9.311764001846313 (s)
# ------------------------------
# Iteration (train phase) 153/300
# Finished in 9.578666687011719 (s)
# ------------------------------
# Iteration (train phase) 154/300
# Finished in 9.571374654769897 (s)
# ------------------------------
# Iteration (train phase) 155/300
# Finished in 9.754863739013672 (s)
# ------------------------------
# Iteration (train phase) 156/300
# Finished in 9.44020390510559 (s)
# ------------------------------
# Iteration (train phase) 157/300
# Finished in 10.09300422668457 (s)
# ------------------------------
# Iteration (train phase) 158/300
# Finished in 9.42275333404541 (s)
# ------------------------------
# Iteration (train phase) 159/300
# Finished in 9.89408540725708 (s)
# ------------------------------
# Iteration (train phase) 160/300
# Finished in 9.61914324760437 (s)
# ------------------------------
# Iteration (train phase) 161/300
# Finished in 9.930099964141846 (s)
# ------------------------------
# Iteration (train phase) 162/300
# Finished in 9.87434196472168 (s)
# ------------------------------
# Iteration (train phase) 163/300
# Finished in 9.734827756881714 (s)
# ------------------------------
# Iteration (train phase) 164/300
# Finished in 9.607495546340942 (s)
# ------------------------------
# Iteration (train phase) 165/300
# Finished in 9.53934359550476 (s)
# ------------------------------
# Iteration (train phase) 166/300
# Finished in 9.703742980957031 (s)
# ------------------------------
# Iteration (train phase) 167/300
# Finished in 9.820037603378296 (s)
# ------------------------------
# Iteration (train phase) 168/300
# Finished in 9.758804321289062 (s)
# ------------------------------
# Iteration (train phase) 169/300
# Finished in 9.85836935043335 (s)
# ------------------------------
# Iteration (train phase) 170/300
# Finished in 9.797041893005371 (s)
# ------------------------------
# Iteration (train phase) 171/300
# Finished in 9.916873216629028 (s)
# ------------------------------
# Iteration (train phase) 172/300
# Finished in 9.452751636505127 (s)
# ------------------------------
# Iteration (train phase) 173/300
# Finished in 10.018146276473999 (s)
# ------------------------------
# Iteration (train phase) 174/300
# Finished in 9.754371166229248 (s)
# ------------------------------
# Iteration (train phase) 175/300
# Finished in 9.637985229492188 (s)
# ------------------------------
# Iteration (train phase) 176/300
# Finished in 9.651490449905396 (s)
# ------------------------------
# Iteration (train phase) 177/300
# Finished in 9.859527587890625 (s)
# ------------------------------
# Iteration (train phase) 178/300
# Finished in 9.811754703521729 (s)
# ------------------------------
# Iteration (train phase) 179/300
# Finished in 9.88654351234436 (s)
# ------------------------------
# Iteration (train phase) 180/300
# Finished in 9.551822662353516 (s)
# ------------------------------
# Iteration (train phase) 181/300
# Finished in 10.221092224121094 (s)
# ------------------------------
# Iteration (train phase) 182/300
# Finished in 9.71287727355957 (s)
# ------------------------------
# Iteration (train phase) 183/300
# Finished in 9.554056406021118 (s)
# ------------------------------
# Iteration (train phase) 184/300
# Finished in 11.560544967651367 (s)
# ------------------------------
# Iteration (train phase) 185/300
# Finished in 10.0780189037323 (s)
# ------------------------------
# Iteration (train phase) 186/300
# Finished in 9.92114806175232 (s)
# ------------------------------
# Iteration (train phase) 187/300
# Finished in 10.193588733673096 (s)
# ------------------------------
# Iteration (train phase) 188/300
# Finished in 11.5608389377594 (s)
# ------------------------------
# Iteration (train phase) 189/300
# Finished in 9.760834693908691 (s)
# ------------------------------
# Iteration (train phase) 190/300
# Finished in 10.166931629180908 (s)
# ------------------------------
# Iteration (train phase) 191/300
# Finished in 9.741429090499878 (s)
# ------------------------------
# Iteration (train phase) 192/300
# Finished in 11.77219820022583 (s)
# ------------------------------
# Iteration (train phase) 193/300
# Finished in 9.515995025634766 (s)
# ------------------------------
# Iteration (train phase) 194/300
# Finished in 10.20783543586731 (s)
# ------------------------------
# Iteration (train phase) 195/300
# Finished in 10.732183694839478 (s)
# ------------------------------
# Iteration (train phase) 196/300
# Finished in 11.790080070495605 (s)
# ------------------------------
# Iteration (train phase) 197/300
# Finished in 9.573539972305298 (s)
# ------------------------------
# Iteration (train phase) 198/300
# Finished in 9.861774921417236 (s)
# ------------------------------
# Iteration (train phase) 199/300
# Finished in 10.160706281661987 (s)
# ------------------------------
# Iteration (train phase) 200/300
# Finished in 10.49927806854248 (s)
# ------------------------------
# Iteration (train phase) 201/300
# Finished in 10.258483648300171 (s)
# ------------------------------
# Iteration (train phase) 202/300
# Finished in 9.59408950805664 (s)
# ------------------------------
# Iteration (train phase) 203/300
# Finished in 10.200674533843994 (s)
# ------------------------------
# Iteration (train phase) 204/300
# Finished in 9.619446992874146 (s)
# ------------------------------
# Iteration (train phase) 205/300
# Finished in 10.214011192321777 (s)
# ------------------------------
# Iteration (train phase) 206/300
# Finished in 10.65989875793457 (s)
# ------------------------------
# Iteration (train phase) 207/300
# Finished in 10.281698942184448 (s)
# ------------------------------
# Iteration (train phase) 208/300
# Finished in 9.952688694000244 (s)
# ------------------------------
# Iteration (train phase) 209/300
# Finished in 10.581684350967407 (s)
# ------------------------------
# Iteration (train phase) 210/300
# Finished in 10.431579113006592 (s)
# ------------------------------
# Iteration (train phase) 211/300
# Finished in 9.892749071121216 (s)
# ------------------------------
# Iteration (train phase) 212/300
# Finished in 10.91304874420166 (s)
# ------------------------------
# Iteration (train phase) 213/300
# Finished in 10.009600162506104 (s)
# ------------------------------
# Iteration (train phase) 214/300
# Finished in 10.4816415309906 (s)
# ------------------------------
# Iteration (train phase) 215/300
# Finished in 10.295425415039062 (s)
# ------------------------------
# Iteration (train phase) 216/300
# Finished in 10.491200685501099 (s)
# ------------------------------
# Iteration (train phase) 217/300
# Finished in 10.41627836227417 (s)
# ------------------------------
# Iteration (train phase) 218/300
# Finished in 10.762136936187744 (s)
# ------------------------------
# Iteration (train phase) 219/300
# Finished in 9.992929220199585 (s)
# ------------------------------
# Iteration (train phase) 220/300
# Finished in 9.725871801376343 (s)
# ------------------------------
# Iteration (train phase) 221/300
# Finished in 10.311781883239746 (s)
# ------------------------------
# Iteration (train phase) 222/300
# Finished in 10.392211437225342 (s)
# ------------------------------
# Iteration (train phase) 223/300
# Finished in 10.734314441680908 (s)
# ------------------------------
# Iteration (train phase) 224/300
# Finished in 9.91797161102295 (s)
# ------------------------------
# Iteration (train phase) 225/300
# Finished in 10.234118223190308 (s)
# ------------------------------
# Iteration (train phase) 226/300
# Finished in 10.32330322265625 (s)
# ------------------------------
# Iteration (train phase) 227/300
# Finished in 10.031309366226196 (s)
# ------------------------------
# Iteration (train phase) 228/300
# Finished in 10.153838634490967 (s)
# ------------------------------
# Iteration (train phase) 229/300
# Finished in 9.922815799713135 (s)
# ------------------------------
# Iteration (train phase) 230/300
# Finished in 10.518964290618896 (s)
# ------------------------------
# Iteration (train phase) 231/300
# Finished in 9.594567060470581 (s)
# ------------------------------
# Iteration (train phase) 232/300
# Finished in 9.982747077941895 (s)
# ------------------------------
# Iteration (train phase) 233/300
# Finished in 10.001472234725952 (s)
# ------------------------------
# Iteration (train phase) 234/300
# Finished in 10.856248617172241 (s)
# ------------------------------
# Iteration (train phase) 235/300
# Finished in 10.656330108642578 (s)
# ------------------------------
# Iteration (train phase) 236/300
# Finished in 9.794811964035034 (s)
# ------------------------------
# Iteration (train phase) 237/300
# Finished in 10.133522987365723 (s)
# ------------------------------
# Iteration (train phase) 238/300
# Finished in 10.253012657165527 (s)
# ------------------------------
# Iteration (train phase) 239/300
# Finished in 10.196236371994019 (s)
# ------------------------------
# Iteration (train phase) 240/300
# Finished in 10.333752632141113 (s)
# ------------------------------
# Iteration (train phase) 241/300
# Finished in 11.702711820602417 (s)
# ------------------------------
# Iteration (train phase) 242/300
# Finished in 10.734050989151001 (s)
# ------------------------------
# Iteration (train phase) 243/300
# Finished in 10.198647499084473 (s)
# ------------------------------
# Iteration (train phase) 244/300
# Finished in 10.098263502120972 (s)
# ------------------------------
# Iteration (train phase) 245/300
# Finished in 12.07142448425293 (s)
# ------------------------------
# Iteration (train phase) 246/300
# Finished in 9.914608716964722 (s)
# ------------------------------
# Iteration (train phase) 247/300
# Finished in 10.799882411956787 (s)
# ------------------------------
# Iteration (train phase) 248/300
# Finished in 10.722229957580566 (s)
# ------------------------------
# Iteration (train phase) 249/300
# Finished in 12.321889877319336 (s)
# ------------------------------
# Iteration (train phase) 250/300
# Finished in 9.946232557296753 (s)
# ------------------------------
# Iteration (train phase) 251/300
# Finished in 10.539482355117798 (s)
# ------------------------------
# Iteration (train phase) 252/300
# Finished in 10.358401775360107 (s)
# ------------------------------
# Iteration (train phase) 253/300
# Finished in 12.431300401687622 (s)
# ------------------------------
# Iteration (train phase) 254/300
# Finished in 10.976070165634155 (s)
# ------------------------------
# Iteration (train phase) 255/300
# Finished in 10.37657618522644 (s)
# ------------------------------
# Iteration (train phase) 256/300
# Finished in 10.57941746711731 (s)
# ------------------------------
# Iteration (train phase) 257/300
# Finished in 11.89989709854126 (s)
# ------------------------------
# Iteration (train phase) 258/300
# Finished in 10.174500465393066 (s)
# ------------------------------
# Iteration (train phase) 259/300
# Finished in 10.860753536224365 (s)
# ------------------------------
# Iteration (train phase) 260/300
# Finished in 10.237320184707642 (s)
# ------------------------------
# Iteration (train phase) 261/300
# Finished in 11.074121475219727 (s)
# ------------------------------
# Iteration (train phase) 262/300
# Finished in 10.302551984786987 (s)
# ------------------------------
# Iteration (train phase) 263/300
# Finished in 10.319869995117188 (s)
# ------------------------------
# Iteration (train phase) 264/300
# Finished in 9.617676019668579 (s)
# ------------------------------
# Iteration (train phase) 265/300
# Finished in 11.031540393829346 (s)
# ------------------------------
# Iteration (train phase) 266/300
# Finished in 10.297877073287964 (s)
# ------------------------------
# Iteration (train phase) 267/300
# Finished in 9.977473497390747 (s)
# ------------------------------
# Iteration (train phase) 268/300
# Finished in 10.212136268615723 (s)
# ------------------------------
# Iteration (train phase) 269/300
# Finished in 9.711861371994019 (s)
# ------------------------------
# Iteration (train phase) 270/300
# Finished in 9.613391876220703 (s)
# ------------------------------
# Iteration (train phase) 271/300
# Finished in 9.813411235809326 (s)
# ------------------------------
# Iteration (train phase) 272/300
# Finished in 9.635268211364746 (s)
# ------------------------------
# Iteration (train phase) 273/300
# Finished in 9.919827461242676 (s)
# ------------------------------
# Iteration (train phase) 274/300
# Finished in 10.204014301300049 (s)
# ------------------------------
# Iteration (train phase) 275/300
# Finished in 9.683326959609985 (s)
# ------------------------------
# Iteration (train phase) 276/300
# Finished in 9.791951179504395 (s)
# ------------------------------
# Iteration (train phase) 277/300
# Finished in 10.222168684005737 (s)
# ------------------------------
# Iteration (train phase) 278/300
# Finished in 10.1866614818573 (s)
# ------------------------------
# Iteration (train phase) 279/300
# Finished in 9.920527458190918 (s)
# ------------------------------
# Iteration (train phase) 280/300
# Finished in 9.83695650100708 (s)
# ------------------------------
# Iteration (train phase) 281/300
# Finished in 10.195754766464233 (s)
# ------------------------------
# Iteration (train phase) 282/300
# Finished in 10.003374338150024 (s)
# ------------------------------
# Iteration (train phase) 283/300
# Finished in 9.813817501068115 (s)
# ------------------------------
# Iteration (train phase) 284/300
# Finished in 9.555763959884644 (s)
# ------------------------------
# Iteration (train phase) 285/300
# Finished in 10.469421148300171 (s)
# ------------------------------
# Iteration (train phase) 286/300
# Finished in 10.177277326583862 (s)
# ------------------------------
# Iteration (train phase) 287/300
# Finished in 10.002593040466309 (s)
# ------------------------------
# Iteration (train phase) 288/300
# Finished in 9.784054040908813 (s)
# ------------------------------
# Iteration (train phase) 289/300
# Finished in 9.77394413948059 (s)
# ------------------------------
# Iteration (train phase) 290/300
# Finished in 11.036866188049316 (s)
# ------------------------------
# Iteration (train phase) 291/300
# Finished in 9.439602851867676 (s)
# ------------------------------
# Iteration (train phase) 292/300
# Finished in 10.053592681884766 (s)
# ------------------------------
# Iteration (train phase) 293/300
# Finished in 9.757698059082031 (s)
# ------------------------------
# Iteration (train phase) 294/300
# Finished in 11.43717360496521 (s)
# ------------------------------
# Iteration (train phase) 295/300
# Finished in 9.53481650352478 (s)
# ------------------------------
# Iteration (train phase) 296/300
# Finished in 9.772588968276978 (s)
# ------------------------------
# Iteration (train phase) 297/300
# Finished in 9.223592758178711 (s)
# ------------------------------
# Iteration (train phase) 298/300
# Finished in 10.319414854049683 (s)
# ------------------------------
# Iteration (train phase) 299/300
# Finished in 9.842087984085083 (s)
# ------------------------------
# Iteration (train phase) 300/300
# Finished in 10.44371747970581 (s)
# ------------------------------
# Iteration (validation phase) 1/100
# Finished in 9.596644639968872 (s)
# ------------------------------
# Iteration (validation phase) 2/100
# Finished in 9.203480005264282 (s)
# ------------------------------
# Iteration (validation phase) 3/100
# Finished in 8.698611736297607 (s)
# ------------------------------
# Iteration (validation phase) 4/100
# Finished in 8.912530899047852 (s)
# ------------------------------
# Iteration (validation phase) 5/100
# Finished in 8.66100287437439 (s)
# ------------------------------
# Iteration (validation phase) 6/100
# Finished in 9.31379771232605 (s)
# ------------------------------
# Iteration (validation phase) 7/100
# Finished in 10.198936700820923 (s)
# ------------------------------
# Iteration (validation phase) 8/100
# Finished in 9.264423847198486 (s)
# ------------------------------
# Iteration (validation phase) 9/100
# Finished in 8.816073894500732 (s)
# ------------------------------
# Iteration (validation phase) 10/100
# Finished in 8.635966062545776 (s)
# ------------------------------
# Iteration (validation phase) 11/100
# Finished in 10.300004959106445 (s)
# ------------------------------
# Iteration (validation phase) 12/100
# Finished in 8.864298343658447 (s)
# ------------------------------
# Iteration (validation phase) 13/100
# Finished in 9.097606658935547 (s)
# ------------------------------
# Iteration (validation phase) 14/100
# Finished in 8.697582483291626 (s)
# ------------------------------
# Iteration (validation phase) 15/100
# Finished in 9.01692247390747 (s)
# ------------------------------
# Iteration (validation phase) 16/100
# Finished in 9.101949214935303 (s)
# ------------------------------
# Iteration (validation phase) 17/100
# Finished in 9.165682792663574 (s)
# ------------------------------
# Iteration (validation phase) 18/100
# Finished in 9.414674043655396 (s)
# ------------------------------
# Iteration (validation phase) 19/100
# Finished in 9.637696266174316 (s)
# ------------------------------
# Iteration (validation phase) 20/100
# Finished in 10.944361686706543 (s)
# ------------------------------
# Iteration (validation phase) 21/100
# Finished in 9.555577516555786 (s)
# ------------------------------
# Iteration (validation phase) 22/100
# Finished in 9.261350631713867 (s)
# ------------------------------
# Iteration (validation phase) 23/100
# Finished in 9.134300470352173 (s)
# ------------------------------
# Iteration (validation phase) 24/100
# Finished in 9.534114360809326 (s)
# ------------------------------
# Iteration (validation phase) 25/100
# Finished in 9.577234745025635 (s)
# ------------------------------
# Iteration (validation phase) 26/100
# Finished in 9.331469535827637 (s)
# ------------------------------
# Iteration (validation phase) 27/100
# Finished in 9.083265781402588 (s)
# ------------------------------
# Iteration (validation phase) 28/100
# Finished in 8.775084495544434 (s)
# ------------------------------
# Iteration (validation phase) 29/100
# Finished in 8.956077098846436 (s)
# ------------------------------
# Iteration (validation phase) 30/100
# Finished in 8.903858423233032 (s)
# ------------------------------
# Iteration (validation phase) 31/100
# Finished in 8.643335342407227 (s)
# ------------------------------
# Iteration (validation phase) 32/100
# Finished in 8.619958400726318 (s)
# ------------------------------
# Iteration (validation phase) 33/100
# Finished in 10.573711156845093 (s)
# ------------------------------
# Iteration (validation phase) 34/100
# Finished in 8.82382583618164 (s)
# ------------------------------
# Iteration (validation phase) 35/100
# Finished in 8.621104001998901 (s)
# ------------------------------
# Iteration (validation phase) 36/100
# Finished in 8.452317714691162 (s)
# ------------------------------
# Iteration (validation phase) 37/100
# Finished in 9.406974792480469 (s)
# ------------------------------
# Iteration (validation phase) 38/100
# Finished in 9.616477489471436 (s)
# ------------------------------
# Iteration (validation phase) 39/100
# Finished in 8.482279777526855 (s)
# ------------------------------
# Iteration (validation phase) 40/100
# Finished in 9.013360023498535 (s)
# ------------------------------
# Iteration (validation phase) 41/100
# Finished in 8.918741941452026 (s)
# ------------------------------
# Iteration (validation phase) 42/100
# Finished in 10.32987666130066 (s)
# ------------------------------
# Iteration (validation phase) 43/100
# Finished in 8.679403305053711 (s)
# ------------------------------
# Iteration (validation phase) 44/100
# Finished in 9.094700336456299 (s)
# ------------------------------
# Iteration (validation phase) 45/100
# Finished in 8.79313039779663 (s)
# ------------------------------
# Iteration (validation phase) 46/100
# Finished in 8.63369369506836 (s)
# ------------------------------
# Iteration (validation phase) 47/100
# Finished in 8.829284191131592 (s)
# ------------------------------
# Iteration (validation phase) 48/100
# Finished in 9.21118688583374 (s)
# ------------------------------
# Iteration (validation phase) 49/100
# Finished in 8.705101728439331 (s)
# ------------------------------
# Iteration (validation phase) 50/100
# Finished in 9.316906213760376 (s)
# ------------------------------
# Iteration (validation phase) 51/100
# Finished in 10.742849111557007 (s)
# ------------------------------
# Iteration (validation phase) 52/100
# Finished in 9.51677942276001 (s)
# ------------------------------
# Iteration (validation phase) 53/100
# Finished in 8.818228483200073 (s)
# ------------------------------
# Iteration (validation phase) 54/100
# Finished in 8.70598816871643 (s)
# ------------------------------
# Iteration (validation phase) 55/100
# Finished in 10.160809993743896 (s)
# ------------------------------
# Iteration (validation phase) 56/100
# Finished in 9.001071691513062 (s)
# ------------------------------
# Iteration (validation phase) 57/100
# Finished in 8.85080599784851 (s)
# ------------------------------
# Iteration (validation phase) 58/100
# Finished in 8.620444059371948 (s)
# ------------------------------
# Iteration (validation phase) 59/100
# Finished in 9.378714799880981 (s)
# ------------------------------
# Iteration (validation phase) 60/100
# Finished in 9.130787372589111 (s)
# ------------------------------
# Iteration (validation phase) 61/100
# Finished in 8.97943639755249 (s)
# ------------------------------
# Iteration (validation phase) 62/100
# Finished in 9.257625102996826 (s)
# ------------------------------
# Iteration (validation phase) 63/100
# Finished in 8.786475896835327 (s)
# ------------------------------
# Iteration (validation phase) 64/100
# Finished in 10.256247282028198 (s)
# ------------------------------
# Iteration (validation phase) 65/100
# Finished in 9.153682470321655 (s)
# ------------------------------
# Iteration (validation phase) 66/100
# Finished in 8.546467542648315 (s)
# ------------------------------
# Iteration (validation phase) 67/100
# Finished in 8.63907527923584 (s)
# ------------------------------
# Iteration (validation phase) 68/100
# Finished in 8.768038034439087 (s)
# ------------------------------
# Iteration (validation phase) 69/100
# Finished in 8.851824522018433 (s)
# ------------------------------
# Iteration (validation phase) 70/100
# Finished in 8.971304178237915 (s)
# ------------------------------
# Iteration (validation phase) 71/100
# Finished in 8.937523126602173 (s)
# ------------------------------
# Iteration (validation phase) 72/100
# Finished in 9.059305191040039 (s)
# ------------------------------
# Iteration (validation phase) 73/100
# Finished in 10.874735116958618 (s)
# ------------------------------
# Iteration (validation phase) 74/100
# Finished in 9.113154411315918 (s)
# ------------------------------
# Iteration (validation phase) 75/100
# Finished in 8.79683542251587 (s)
# ------------------------------
# Iteration (validation phase) 76/100
# Finished in 8.697404146194458 (s)
# ------------------------------
# Iteration (validation phase) 77/100
# Finished in 9.290768146514893 (s)
# ------------------------------
# Iteration (validation phase) 78/100
# Finished in 9.397546529769897 (s)
# ------------------------------
# Iteration (validation phase) 79/100
# Finished in 9.001047134399414 (s)
# ------------------------------
# Iteration (validation phase) 80/100
# Finished in 8.928089380264282 (s)
# ------------------------------
# Iteration (validation phase) 81/100
# Finished in 9.092088222503662 (s)
# ------------------------------
# Iteration (validation phase) 82/100
# Finished in 8.651259660720825 (s)
# ------------------------------
# Iteration (validation phase) 83/100
# Finished in 9.562885761260986 (s)
# ------------------------------
# Iteration (validation phase) 84/100
# Finished in 9.072349309921265 (s)
# ------------------------------
# Iteration (validation phase) 85/100
# Finished in 9.040173768997192 (s)
# ------------------------------
# Iteration (validation phase) 86/100
# Finished in 11.293498754501343 (s)
# ------------------------------
# Iteration (validation phase) 87/100
# Finished in 9.411922931671143 (s)
# ------------------------------
# Iteration (validation phase) 88/100
# Finished in 9.057241201400757 (s)
# ------------------------------
# Iteration (validation phase) 89/100
# Finished in 9.174467325210571 (s)
# ------------------------------
# Iteration (validation phase) 90/100
# Finished in 9.474352359771729 (s)
# ------------------------------
# Iteration (validation phase) 91/100
# Finished in 8.736515998840332 (s)
# ------------------------------
# Iteration (validation phase) 92/100
# Finished in 8.656895875930786 (s)
# ------------------------------
# Iteration (validation phase) 93/100
# Finished in 8.81318712234497 (s)
# ------------------------------
# Iteration (validation phase) 94/100
# Finished in 8.722177028656006 (s)
# ------------------------------
# Iteration (validation phase) 95/100
# Finished in 9.516971111297607 (s)
# ------------------------------
# Iteration (validation phase) 96/100
# Finished in 8.722470045089722 (s)
# ------------------------------
# Iteration (validation phase) 97/100
# Finished in 8.719500064849854 (s)
# ------------------------------
# Iteration (validation phase) 98/100
# Finished in 9.024428844451904 (s)
# ------------------------------
# Iteration (validation phase) 99/100
# Finished in 10.264920234680176 (s)
# ------------------------------
# Iteration (validation phase) 100/100
# Finished in 8.944251537322998 (s)
# Epoch 1 - accuracy: 0.996
# ------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_68/1135267508.py in <module>
#      74
#      75     # Save model
# ---> 76     model_file_path = model_path + "resnet18_trained_model_epoch_{}.pth".format(epoch+1)
#      77     torch.save(model.state_dict(), model_file_path)
#      78
#
# NameError: name 'model_path' is not defined

# %% [markdown]
# <b>Print out the Accuracy and plot the loss stored in the list <code>loss_list</code> for every iteration and take a screen shot.</b>

# %%
accuracy
# Out:
# 0.9948

# %%
plt.plot(loss_list)
plt.xlabel("iteration")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# <h2 id="Question_3">Question 3:Find the misclassified samples</h2>

# %% [markdown]
# <b>Identify the first four misclassified samples using the validation data:</b>

# %%
count = 0
max_num_of_items = 4  # first four mis-classified samples
validation_loader_batch_one = torch.utils.data.DataLoader(dataset=validation_dataset, batch_size=1)

for i, (x_test, y_test) in enumerate(validation_loader_batch_one):
    # set model to eval
    model.eval()
    
    # make a prediction
    z = model(x_test)
    
    # find max
    _, yhat = torch.max(z.data, 1)
    
    # print mis-classified samples
    if yhat != y_test:
        print("Sample : {}; Expected Label: {}; Obtained Label: {}".format(str(i), str(y_test), str(yhat)))
        count += 1
        if count >= max_num_of_items:
            break
    # end if
# end for
# Out:
# Sample : 22; Expected Label: tensor([1]); Obtained Label: tensor([0])
# Sample : 101; Expected Label: tensor([0]); Obtained Label: tensor([1])
# Sample : 134; Expected Label: tensor([1]); Obtained Label: tensor([0])
# Sample : 182; Expected Label: tensor([1]); Obtained Label: tensor([0])

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/share-notebooks.html?utm_source=skills_network&utm_content=in_lab_content_link&utm_id=Lab-IBMDeveloperSkillsNetwork-DL0321EN-SkillsNetwork"> CLICK HERE </a> Click here to see how to share your notebook.

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-09-21  | 2.0  | Shubham  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>

# %% [markdown]
# Copyright &copy; 2018 <a href="cognitiveclass.ai?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu">cognitiveclass.ai</a>. This notebook and its source code are released under the terms of the <a href="https://bigdatauniversity.com/mit-license/">MIT License</a>.
